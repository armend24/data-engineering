# %%
# %run "/Workspace/Users/armendlearns@gmail.com/data-engineering/My-Folder/(Clone)-Copy-Datasets"

# %%
# %python
files = dbutils.fs.ls(f"{dataset_bookstore}/customers-json")
display(files)

# %%
# %sql
SELECT * FROM json.`${dataset.bookstore}/customers-json/export_001.json`

# %%
# %sql
CREATE TABLE IF NOT EXISTS AS
SELECT * FROM json.`${dataset.bookstore}/customers-json`

# %%
# %sql
ALTER TABLE default.as RENAME TO customers

# %%
# %sql
SELECT *, input_file_name() source_file FROM default.customers

# %%
# %sql
select * from csv.`${dataset.bookstore}/customers-json/export_001.json`

# %%
# %sql
create table if not exists books.csv_books as
select * from read_files('${dataset.bookstore}/books-csv',
    header => true,
    delimiter => ';',
    format => 'csv'
)

# %%
# %sql
create database demoworkspace.books

# %%
# %sql
describe extended books.csv_books

# %%
# %sql
select * from books.csv_books

# %%
# %python
spark.read.table("books.csv_books").write.mode("append").format("csv").option("header", True).option("delimiter", ";").save(f"{dataset_bookstore}/books-csv")

# %%
# %sql
select * from csv.`${dataset.bookstore}/books-csv`

# %%
# %sql
select * from books.csv_books

# %%
# %python
files = dbutils.fs.ls(f"{dataset_bookstore}/books-csv")
display(files)

# %%
# %sql
create or replace table csv_experiment as
select * from csv.`${dataset.bookstore}/books-csv`;

select * from csv_experiment

# %%
# %sql
create or replace temp view csv_experiment_bridge (
    book_id string,
    title string,
    author string,
    category string,
    price double
) 
using csv
options (
    path = "${dataset.bookstore}/books-csv",
    header = true,
    delimiter = ";"
);

create or replace table csv_experiment as
select * from csv_experiment_bridge;

select * from csv_experiment;

# %%
# %sql
create or replace table csv_experiment as
select book_id, title, author, category, price
from read_files(
    "${dataset.bookstore}/books-csv",
    header => true,
    delimiter => ";",
    format => "csv",
    rescuedDataColumn => "_rescued_data"
);

select * from csv_experiment;

# %%
# %sql
SELECT 
  *, 
  _metadata.file_name,
  _metadata.file_path
FROM read_files(
    "${dataset.bookstore}/customers-json/export_001.json",
    format => "json"
)

# %%
# %sql
SELECT * FROM read_files(
    '/Volumes/demoworkspace/default/dump/books-csv',
    header => true,
    delimiter => ';',
    format => 'csv',
    rescuedDataColumn => 'rescued_data'
)
