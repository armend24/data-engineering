# %%
print("Hello World!")

# %%
# %sql
SELECT "Hello Data Engineering World!"

# %% [markdown]
# <table>
#     <tr>
#         <th> First Name </th>
#         <th> Last Name </th>
#         <th> Age </th>
#     </tr>
#     <tr>
#         <td> Lemon </td>
#         <td> Citrus </td>
#         <td> 24 </td>
#     </tr>
# </table>

# %%
# %run "../../Includes/Setup"

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
# %fs ls "dbfs:/databricks-datasets/COVID/.DS_Store"

# %%
# %sql
select *
from read_files(
    "dbfs:/databricks-datasets/COVID/",
    format => 'csv',
    header => true
)

# %%
files = dbutils.fs.ls("/databricks-datasets/COVID/.DS_Store")
display(files)
